# %% [markdown]
# # Imports

# %%
#LDA library
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel
from gensim.matutils import Sparse2Corpus

# %% [markdown]
# Questão 1: Implementação LDA

# %% [markdown]
# Dado o conjunto de documentos abaixo, utilize a biblioteca `gensim` para criar um modelo LDA com 2 tópicos. Mostre as palavras mais representativas de cada tópico.

# %%
documentos = [
    "Cachorros são ótimos animais de estimação",
    "Gatos também são bons animais de estimação",
    "Eu gosto de cachorros e gatos",
    "Carros são úteis para transporte",
    "Trens são uma boa alternativa de transporte"
]

# %% [markdown]
# Questão 2: Interpretação LDA

# %% [markdown]
# O que achaste dos resultados acima? LDA precisa de pre processamento dos documentos? Fizeste acima preprocessamento? Se sim qual método e qual a justificação?

# %% [markdown]
# Questão 3: Interpretação LDA 2

# %% [markdown]
# Imagine que você treinou um modelo LDA com 3 tópicos em um conjunto de documentos e obteve as seguintes palavras mais representativas de cada tópico:
# * Tópico 0: [‘cachorro’, ‘gato’, ‘animal’, ‘estimação’]
# * Tópico 1: [‘carro’, ‘transporte’, ‘trânsito’, ‘veículo’]
# * Tópico 2: [‘alimento’, ‘fruta’, ‘mercado’, ‘preço’]

# %% [markdown]
# a) Explique, de forma breve, como interpretar os tópicos gerados.

# %% [markdown]
# b) Como você utilizaria o modelo LDA para categorizar um novo documento "Eu comprei frutas no mercado hoje"? Use o modelo que da Questao 1.

# %% [markdown]
# Questão 3: Avaliação de Modelo LDA usando Classificação Manual

# %% [markdown]
# Você tem o seguinte conjunto de documentos, onde cada documento já foi classificado manualmente em um dos dois tópicos:

# %%
documentos = [
    "Os gatos são animais muito independentes",  # Tópico 0: Animais
    "Cachorros adoram brincar com bolas",  # Tópico 0: Animais
    "Trens são uma alternativa ao transporte rodoviário",  # Tópico 1: Transporte
    "Carros são úteis para transporte urbano",  # Tópico 1: Transporte
    "Eu adoro observar os pássaros voando",  # Tópico 0: Animais
    "O transporte público é essencial em grandes cidades",  # Tópico 1: Transporte
]
# Classificação manual dos documentos:
classes_manualmente_definidas = [0, 0, 1, 1, 0, 1]  # 0 = Animais, 1 = Transporte

# %% [markdown]
# 1. Treine um modelo LDA com 2 tópicos usando a biblioteca `gensim`.
# 2. Use o modelo para prever os tópicos dos documentos e compare essas previsões com as classes manualmente definidas.
# 3. Calcule a acurácia entre as previsões do modelo e as classes manuais.
