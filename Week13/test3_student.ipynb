# %% [markdown]
# ###Task1: Sentiment Analysis with BERT
#
# 1. Load the provided dataset, `dataset_sentiment.xlsx`.
# 2. Using the loaded dataset, apply a BERT-based sentiment analysis model to classify the `text` column for the first 500 data points.
# 3. Compare the predictions of your chosen model with the `sentiment` column.
# 4. Pay close attention to the number of labels when selecting the model.
# 5. To evaluate the model's performance, use a confusion matrix.

# %% [markdown]
# ### Task 2: PCA Analysis with BERT
#
# 1. Consider the 10 uses of the polysemous word **'light'** provided below.
# 2. Generate the vector representations for each occurrence of the word **'light'** using the model `google-bert/bert-base-uncased`.
# 3. Apply **PCA** to reduce the dimensionality of these vectors and create a **2D plot**.
# 4. Answer the following questions based on the plot:
#    - Which occurrences of **'light'** are the closest to each other?
#    - Which occurrences are the most distant?
#    - Justify your answers.

# %%
examples = [
    "Turn off the light when you leave the room.",
    "The box is very light, you can carry it easily.",
    "She has light blue eyes.",
    "The morning light filled the room with warmth.",
    "He prefers to eat a light meal before exercising.",
    "The lamp gives a soft and warm light.",
    "The idea suddenly came to him, like a light in the dark.",
    "The traffic light turned red.",
    "They built a fire to light their way through the forest.",
    "This poem is written in a light and humorous tone.",
]
