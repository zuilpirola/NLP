# %% [markdown]
# # Imports

# %%
#LDA library
import pandas as pd
import gensim
import gensim.corpora as corpora
from gensim.models.ldamodel import LdaModel

# %% [markdown]
# # Load dataset

# %% [markdown]
# 1 - Load the data from the file `dados.csv`

# %% [markdown]
# 2 - To run the LDA, it is necessary to preprocess the text. Create a function that preprocesses the imported text. Perform the preprocessing afterward. Your function must include at least tokenization, lemmatization, and removal of stopwords.

# %% [markdown]
# 3 - We are using the `Gensim` library. Use `corpora.Dictionary()` to create a dictionary that we will use in the model. What is the purpose of this step?

# %% [markdown]
# 4 - As a second input, it is necessary to create the corpus for the `LdaModel()` function. Read the documentation and create a compatible corpus based on the preprocessing you have already performed.

# %% [markdown]
# 5 - Create a code using `LdaModel()` that considers the number of topics as 3.

# %% [markdown]
# 6 - Without any additional flags, running an LDA model will always yield a different result. How can we ensure that the same model produces consistent results for future analyses?

# %% [markdown]
# 7 - Using `lda_model.print_topics()`, present the top 10 tokens for each of the generated topics.

# %% [markdown]
# 8 - Based on the tokens generated above and considering the documents in the corpus, create descriptors or labels for each of the topics.

# %% [markdown]
# 10 - Consider the list below:

# %%
classificacoes = [
    (0, "Economia e Finanças"),  # Mercado de ações
    (1, "Tecnologia e Ciência"),  # Inteligência artificial
    (2, "Estilo de Vida e Cultura"),  # Futebol
    (3, "Tecnologia e Ciência"),  # Agricultura sustentável
    (4, "Tecnologia e Ciência"),  # Ficção científica
    (5, "Estilo de Vida e Cultura"),  # Receitas caseiras
    (6, "Economia e Finanças"),  # Educação financeira
    (7, "Tecnologia e Ciência"),  # Descobertas espaciais
    (9, "Estilo de Vida e Cultura"),  # Jogos eletrônicos
    (9, "Estilo de Vida e Cultura"),  # Meditação
]

# %% [markdown]
# Use the distribution generated by your model for each document in the corpus and classify them. Then, compare it with the list above to check if your model correctly identified the manually assigned topics.
